# %%
import pandas as pd

df_report = pd.read_csv("HR.csv")
df_report.columns = df_report.columns.str.lower() #для избежания ошибок
df_report
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df_report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df_report.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  work_accident  left  promotion_last_5years department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df_report.mode()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                 0.1             0.55             4.0                   135
# 1                 NaN              NaN             NaN                   156
#
#    time_spend_company  work_accident  left  promotion_last_5years department  \
# 0                 3.0            0.0   0.0                    0.0      sales
# 1                 NaN            NaN   NaN                    NaN        NaN
#
#   salary
# 0    low
# 1    NaN

# %%
df_report.median()
# Out:
# C:\Users\U_M1B6P\AppData\Local\Temp\ipykernel_12868\2404428738.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_report.median()
# satisfaction_level         0.64
# last_evaluation            0.72
# number_project             4.00
# average_montly_hours     200.00
# time_spend_company         3.00
# work_accident              0.00
# left                       0.00
# promotion_last_5years      0.00
# dtype: float64

# %%
df_report.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df_report.std(ddof=1)
# Out:
# C:\Users\U_M1B6P\AppData\Local\Temp\ipykernel_12868\2795528504.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_report.std(ddof=1)
# satisfaction_level        0.248631
# last_evaluation           0.171169
# number_project            1.232592
# average_montly_hours     49.943099
# time_spend_company        1.460136
# work_accident             0.351719
# left                      0.425924
# promotion_last_5years     0.144281
# dtype: float64

# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from pylab import rcParams
from scipy import stats

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.datasets import fetch_20newsgroups, load_files
from scipy.sparse import csr_matrix

import os
import re

#sns.pairplot(df_report)
#должна работать по логике, а не работает, не буду делать

# %%
df_report.corr()
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.020048           -0.100866
# last_evaluation                    0.339742            0.131591
# number_project                     0.417211            0.196786
# ...

# %%
df_report_numerical.corr(method='spearman')
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.162407        0.005786
# last_evaluation                  0.162407         1.000000        0.350399
# number_project                   0.005786         0.350399        1.000000
# average_montly_hours             0.062000         0.342061        0.397855
# time_spend_company              -0.139428         0.161154        0.251971
# work_accident                    0.056333        -0.005767        0.002328
# left                            -0.365842        -0.002440       -0.019544
# promotion_last_5years            0.022306        -0.007167       -0.002960
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                 0.062000           -0.139428
# last_evaluation                    0.342061            0.161154
# number_project                     0.397855            0.251971
# ...

# %%
xx= df_report_numerical.corr(method='spearman')
sns.heatmap(xx, annot=True)
# Out:
# <AxesSubplot: >

# %%
df_report[['number_project', 'work_accident']].corr(method='spearman')
# Out:
#                 number_project  work_accident
# number_project        1.000000       0.002328
# work_accident         0.002328       1.000000

# %%
df_report.plot(kind='scatter', 
        x='number_project', 
        y='work_accident'
       )
# Out:
# C:\Users\U_M1B6P\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='number_project', ylabel='work_accident'>

# %%
df_report_numerical[['average_montly_hours', 'number_project']].corr(method='spearman')
# Out:
#                       average_montly_hours  number_project
# average_montly_hours              1.000000        0.397855
# number_project                    0.397855        1.000000

# %%
df_report.plot(kind='scatter', 
        x='average_montly_hours', 
        y='number_project'
       )
# Out:
# <AxesSubplot: xlabel='average_montly_hours', ylabel='number_project'>

# %%
from collections import Counter

df_report.groupby(['department']).size()
# Out:
# department
# IT             1227
# RandD           787
# accounting      767
# hr              739
# management      630
# marketing       858
# product_mng     902
# sales          4140
# support        2229
# technical      2720
# dtype: int64

# %%
count_ = df_report['department'].value_counts().sort_values(ascending = False)
count_.plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
Department = df_report.groupby(['department', 'salary'])[['satisfaction_level']].count()
Department.columns = ['count']
Department
# Out:
#                     count
# department  salary
# IT          high       83
#             low       609
#             medium    535
# RandD       high       51
#             low       364
#             medium    372
# accounting  high       74
#             low       358
#             medium    335
# hr          high       45
#             low       335
#             medium    359
# management  high      225
#             low       180
#             medium    225
# marketing   high       80
#             low       402
#             medium    376
# product_mng high       68
#             low       451
#             medium    383
# sales       high      269
#             low      2099
#             medium   1772
# support     high      141
#             low      1146
#             medium    942
# technical   high      201
#             low      1372
#             medium   1147

# %%
Department.unstack()
# Out:
#             count
# salary       high   low medium
# department
# IT             83   609    535
# RandD          51   364    372
# accounting     74   358    335
# hr             45   335    359
# management    225   180    225
# marketing      80   402    376
# product_mng    68   451    383
# sales         269  2099   1772
# support       141  1146    942
# technical     201  1372   1147

# %%
Department.unstack().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='department'>

# %%
df_report.groupby(['department', 'salary', ])[['satisfaction_level']].count()
# Out:
#                     satisfaction_level
# department  salary
# IT          high                    83
#             low                    609
#             medium                 535
# RandD       high                    51
#             low                    364
#             medium                 372
# accounting  high                    74
#             low                    358
#             medium                 335
# hr          high                    45
#             low                    335
#             medium                 359
# management  high                   225
#             low                    180
#             medium                 225
# marketing   high                    80
#             low                    402
#             medium                 376
# product_mng high                    68
#             low                    451
#             medium                 383
# sales       high                   269
# ...

# %%
df_high = df_report[df_report['salary'] == 'high']['average_montly_hours']
df_high
# Out:
# 72       149
# 111      289
# 189      156
# 267      129
# 306      149
#         ...
# 14829    148
# 14868    130
# 14902    159
# 14941    131
# 14980    238
# Name: average_montly_hours, Length: 1237, dtype: int64

# %%
df_low = df_report[df_report['salary'] == 'low']['average_montly_hours']
df_low
# Out:
# 0        157
# 3        223
# 4        159
# 5        153
# 6        247
#         ...
# 14994    151
# 14995    160
# 14996    143
# 14997    280
# 14998    158
# Name: average_montly_hours, Length: 7316, dtype: int64

# %%
from scipy import stats
result = stats.ttest_ind(a=df_low, b=df_high, equal_var=False)
print(result)
if (result.pvalue < 0.001):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не отвергаем нулевую гипотезу')
# Out:
# Ttest_indResult(statistic=0.7624331665385475, pvalue=0.4459045542257889)
# Не отвергаем нулевую гипотезу

# %%
workers = df_report['left'].count()
print(f' Количество сотрудников {workers}')

df_left = df_report.groupby(df_report['left'] == 1)['promotion_last_5years'].sum()
print(f' Сотрудники уволившиеся после повышения : {df_left[1]}')

l = df_left[1]/workers*100
print(f' Доля сотрудников уволившихся после повышения: {l.round(1)}%')

df_not_left = df_report.groupby(df_report['left'] == 0)['promotion_last_5years'].sum()
print(f' Сотрудники оставшиеся работать после повышения : {df_not_left[1]}')

d = df_not_left[1]/workers*100
print(f' Доля сотрудников не уволившихся после повышения: {d.round(1)}%')
# Out:
#  Количество сотрудников 14999
#  Сотрудники уволившиеся после повышения : 19
#  Доля сотрудников уволившихся после повышения: 0.1%
#  Сотрудники оставшиеся работать после повышения : 300
#  Доля сотрудников не уволившихся после повышения: 2.0%

# %%
df_workers_left = df_report.groupby(df_report['left'] == 1)['satisfaction_level'].mean()
df_workers_left
print(f' Средняя оценка удовлетворения у уволившихся : {df_workers_left[1]}')

df_workers_not_left = df_report.groupby(df_report['left'] == 0)['satisfaction_level'].mean()
df_workers_not_left
print(f' Средняя оценка удовлетворения у  работающих : {df_workers_not_left[1]}')
# Out:
#  Средняя оценка удовлетворения у уволившихся : 0.44009801176141133
#  Средняя оценка удовлетворения у  работающих : 0.666809590479524

# %%
df_project_left = df_report.groupby(df_report['left'] == 1)['number_project'].mean()
df_project_left
print(f' Средняя количество проектов у ушедшего сотрудника : {df_project_left[1]}')

df_project_not_left = df_report.groupby(df_report['left'] == 0)['number_project'].mean()
print(f' Средняя количество проектов у оставшегося сотрудника : {df_project_not_left[1]}')
# Out:
#  Средняя количество проектов у ушедшего сотрудника : 3.8555026603192384
#  Средняя количество проектов у оставшегося сотрудника : 3.786664333216661

# %%
df_report_numerical = df_report.drop(['department', 'salary', 'left'], axis=1)
df_report_numerical
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  work_accident  \
# 0                       157                   3              0
# 1                       262                   6              0
# 2                       272                   4              0
# ...

# %%
df_trgt = df_report['left']
y = df_trgt

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_report, y, test_size=0.25, random_state = 12)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 
lda = LinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
model = lda.fit(X_train, y_train)
pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [111], line 6
#       3 from sklearn.preprocessing import StandardScaler
#       5 sc = StandardScaler()
# ----> 6 X_train = sc.fit_transform(X_train)
#       7 X_test = sc.transform(X_test)
#       8 model = lda.fit(X_train, y_train)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:867, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     863 # non-optimized default implementation; override when a better
#     864 # method is possible for a given clustering algorithm
#     865 if y is None:
#     866     # fit method of arity 1 (unsupervised transformation)
# --> 867     return self.fit(X, **fit_params).transform(X)
#     868 else:
#     869     # fit method of arity 2 (supervised transformation)
#     870     return self.fit(X, y, **fit_params).transform(X)
#
# ...

# %%
#lr = LinearDiscriminantAnalysis()

# %%
lr.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [104], line 1
# ----> 1 lr.fit(X_train, y_train)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\discriminant_analysis.py:550, in LinearDiscriminantAnalysis.fit(self, X, y)
#     528 def fit(self, X, y):
#     529     """Fit the Linear Discriminant Analysis model.
#     530
#     531        .. versionchanged:: 0.19
#    (...)
#     548         Fitted estimator.
#     549     """
# --> 550     X, y = self._validate_data(
#     551         X, y, ensure_min_samples=2, dtype=[np.float64, np.float32]
#     552     )
#     553     self.classes_ = unique_labels(y)
#     554     n_samples, _ = X.shape
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [83], line 1
# ----> 1 y_pred = lr.predict(X_test)
#       2 y_pred
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_base.py:447, in LinearClassifierMixin.predict(self, X)
#     433 def predict(self, X):
#     434     """
#     435     Predict class labels for samples in X.
#     436
#    (...)
#     445         Vector containing the class labels for each sample.
#     446     """
# --> 447     scores = self.decision_function(X)
#     448     if len(scores.shape) == 1:
#     449         indices = (scores > 0).astype(int)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\discriminant_analysis.py:715, in LinearDiscriminantAnalysis.decision_function(self, X)
#     695 """Apply decision function to an array of samples.
#     696
# ...

# %%
accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [52], line 1
# ----> 1 accuracy_score(y_test, y_pred)
#
# NameError: name 'accuracy_score' is not defined

# %%
X_test['predickt'] = y_pred 
X_test['test'] = y_test
X_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [55], line 1
# ----> 1 X_test['predickt'] = y_pred
#       2 X_test['test'] = y_test
#       3 X_test
#
# NameError: name 'y_pred' is not defined

# %%
from sklearn.metrics import confusion_matrix

results = confusion_matrix(y_test, y_pred)
